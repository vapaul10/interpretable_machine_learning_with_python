# %% [markdown]
# <a href="https://colab.research.google.com/github/vapaul10/interpretable_machine_learning_with_python/blob/master/2Ch_Function_fetch_and_load.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2Ch Function fetch and load p. 51

# %%
print("Welcome to Machine Learning!")

# %% [markdown]
# This project requires Python 3.7 or above:

# %%
import sys

assert sys.version_info >= (3, 7)

# %% [markdown]
# It also requires Scikit-Learn ≥ 1.0.1:
